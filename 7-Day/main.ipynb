# %%
#Let's read the dataset
import pandas as pd
df = pd.read_csv("../titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Today is the 7 Day of our Machile Learning challenge where we will write a code in order to learn Machine Learning every single day.
# So today we will cover all the topic we covered previous 6 days and will write the code from reading the dataframe till Feature Engineering.
# We will combine all the code into one and after running all the commands we will have prepared dataset for training

# %% [markdown]
# 1 - Step to see overall information about dataset

# %%
#Let's see what contains our dataset
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#What columns does contain our dataset
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Let's see some statistical values
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Let's see dataframes notnull values
df[df.notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#See how many people survivied in the crime 
df[df["Survived"] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#See how many people not survivied in the crime 
df[df["Survived"] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# 2 - Step. Perform some statistical calculations and plotting some data

# %%
mean_age = df["Age"].mean()
median_age = df["Age"].median()
mode_age = df["Age"].mode()[0]
standard_deviation = df["Age"].std()

print("Mean of Age column: ", mean_age)
print("Median of Age column: ", median_age)
print("Mode of Age column: ", mode_age)
print("Standard Deviation of Age column: ", standard_deviation)
# Out:
# Mean of Age column:  29.69911764705882
# Median of Age column:  28.0
# Mode of Age column:  24.0
# Standard Deviation of Age column:  14.526497332334042

# %%
import matplotlib.pyplot as plt
#in this histogram of age we can see that most of the people from titanic dataset were in age between 18 and 40
df["Age"].hist()
# Out:
# <AxesSubplot:>

# %%
#Let's plot a pie chart and see the diffenrece between male and female in dataset
df["Sex"].value_counts(normalize=True).plot.pie(autopct='%.1f %%', ylabel='', legend=True)
# Out:
# <AxesSubplot:>

# %%
#If we will plot a boxplot from Age column we can see that minimum is near 0 and maximum is like in the 60 so all the other values which are below 0 and above 60 we can consider as an outliers
plt.boxplot(df["Age"].dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x146db82e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x146db8940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x146da8fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x146db8e20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x146dc6130>],
#  'means': []}

# %%
#Let's plot a pairplot to see some cases between the columns
import seaborn as sns
sns.pairplot(df)

# %%
#Let's see how many None values we have in each column in our dataset
#So from this we can see that in our Age column we have 177 missing values 687 in Cabin and 2 in Embarked
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Let's make a heatmap in order to see the None values in our dataset
#Using the heatmap we can see visually the missing values in the dataset
import seaborn as sns
sns.heatmap(df.isna().transpose())
# Out:
# <AxesSubplot:>

# %%
#okay now let's work with the missing values as we already know we have missing values in Age, Cabin and Embarked columns
#So let's start from the Age column. There are many ways to work with missing values for example drop all missing values or fullfill the dataframe with median or mean values or just forward or backward fill
#In this case I guess the best method will be to drop all rwos with missing Age values as if we fullfill dataset with another values it will cause misinformation in dataset 
df = df.dropna(axis=0, subset=["Age"])
#here we dropped the rows where Age is not defined values

# %%
#Our next target is Cabin I guess it will be correct if we will drop the whole Cabin column totally as more than half values are missing in this column
df = df.drop(columns=["Cabin"])

# %%
#Now only we left embarked column with Na values 
#As we see only 2 rows has Na values in dataset and Embraked means the port where a passenger boarded the ship so I think here we can just fill the Na values with the mode from Embraked column
#As mode means the most frequent elements from features most probably that 2 people are also from that port which is mostly represented in dataset
# Let's implement the code of it
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
#Let's check another time wheter we have missing values in our dataset or not
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#Now let's identify which columns has the categorical values, they are Sex,Embarked. 
#We can consider that Name is also categorical variable by I think it does not have any effect in predicting who survived or not.
#Let's get the dummy variables by their columns in another dataframes.
Sex = pd.get_dummies(df.Sex)
Embarked = pd.get_dummies(df.Embarked)

# %%
#Now we got 2 dataframes with total 5 columns which we should add to our final dataframe.Let's add them
df = pd.concat([df,Sex,Embarked], axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#These encoders we can get from sklearn library
#Let's import df also, frop Na values also
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#We will appy Label encoder into Sex column in our dataframe 
#create and object of label encoder
le = LabelEncoder()
#Here fit_transform method will take the categorical values and turn it into numerical itself
df["Sex"]=le.fit_transform(df["Sex"])

# %%
#Now let's apply One hot Encoder to our Embarked column
ohe = OneHotEncoder()
df = pd.get_dummies(df, columns=["Embarked"], drop_first=True)

# %%
df_numeric = df.select_dtypes(include=['float64', 'int64'])
df_numeric.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000  0.029340 -0.035349  0.024575  0.036847 -0.082398
# Survived        0.029340  1.000000 -0.359653 -0.538826 -0.077221 -0.017358
# Pclass         -0.035349 -0.359653  1.000000  0.155460 -0.369226  0.067247
# Sex             0.024575 -0.538826  0.155460  1.000000  0.093254 -0.103950
# Age             0.036847 -0.077221 -0.369226  0.093254  1.000000 -0.308247
# SibSp          -0.082398 -0.017358  0.067247 -0.103950 -0.308247  1.000000
# Parch          -0.011617  0.093317  0.025683 -0.246972 -0.189119  0.383820
# Fare            0.009592  0.268189 -0.554182 -0.184994  0.096067  0.138329
#
#                 Parch      Fare
# PassengerId -0.011617  0.009592
# Survived     0.093317  0.268189
# Pclass       0.025683 -0.554182
# Sex         -0.246972 -0.184994
# Age         -0.189119  0.096067
# SibSp        0.383820  0.138329
# Parch        1.000000  0.205119
# ...

# %%
import seaborn as sb
dataplot = sb.heatmap(df_numeric.corr(), cmap="YlGnBu", annot=True)

# %%
#As in our dataset we can see that there is SibSp column which means siblings/spouses aboard and Parch parents/children aboard
#So if we add all of them we can have the full family size
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1  # Add 1 for the passenger themselves

# %%
#Now from created new feature we can create a new feature while checking is the person is alone 
df['IsAlone'] = (df['FamilySize'] == 1).astype(int)

# %%
#Now if see the correlation we can see that isAlone feature effects more than Parch or SibSp for example
#that means we have done good in case of creating new features 
df_numeric = df.select_dtypes(include=['float64', 'int64'])
df_numeric.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000  0.029340 -0.035349  0.024575  0.036847 -0.082398
# Survived        0.029340  1.000000 -0.359653 -0.538826 -0.077221 -0.017358
# Pclass         -0.035349 -0.359653  1.000000  0.155460 -0.369226  0.067247
# Sex             0.024575 -0.538826  0.155460  1.000000  0.093254 -0.103950
# Age             0.036847 -0.077221 -0.369226  0.093254  1.000000 -0.308247
# SibSp          -0.082398 -0.017358  0.067247 -0.103950 -0.308247  1.000000
# Parch          -0.011617  0.093317  0.025683 -0.246972 -0.189119  0.383820
# Fare            0.009592  0.268189 -0.554182 -0.184994  0.096067  0.138329
# FamilySize     -0.058314  0.042787  0.056909 -0.207165 -0.301914  0.847354
# IsAlone         0.059405 -0.196140  0.146320  0.279769  0.198270 -0.629818
#
#                 Parch      Fare  FamilySize   IsAlone
# PassengerId -0.011617  0.009592   -0.058314  0.059405
# ...

# %%
dataplot = sb.heatmap(df_numeric.corr(), cmap="YlGnBu", annot=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.to_csv("../prepared_titanic.csv")

# %% [markdown]
# So today was the 7 Days of Machine Learning challenge. Finally I got prepared dataset for the further steps.
#
# Steps Completed:
#
# Dataset Reading:
#     Loaded the Titanic dataset for analysis and preprocessing.
# Data Visualization:
#     Created insightful plots to understand feature distributions and relationships.
# Handling Missing Values:
#     Identified and addressed all None values in the dataset.
#     Replaced missing values with meaningful substitutes (e.g., median for Age, mode for Embarked).
#     Verified there are no remaining missing values.
# Statistical Analysis:
#     Calculated key statistical metrics:
#     Mean, Median, Mode, and Standard Deviation for numeric features.
#     Gained a better understanding of the dataset's characteristics.
# Categorical Variable Encoding:
#     Converted non-numerical features (Sex and Embarked) into numerical values using encoding techniques (Label Encoding).
# Feature Correlation Analysis:
#     Computed the correlation matrix to find relationships between features.
#     Discovered that Sex and Age are the most impactful features influencing survival.

# %% [markdown]
# Our next 7 days will be Preprocessing and Pipelines.
